# %% [markdown]
# # Clustering Analysis
# Exploração de padrões escondidos com K-Means, DBSCAN e Agglomerative Clustering.

# %%
import pandas as pd
df = pd.read_csv('../data/processed/clean_sensor_readings.csv', parse_dates=['timestamp'])
df.head()
