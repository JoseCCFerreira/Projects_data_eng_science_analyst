# %% [markdown]
# # Data Exploration
# Neste notebook exploraremos os dados de sensores e verificaremos o formato inicial do dataset.

# %%
import pandas as pd
from pathlib import Path
df = pd.read_csv('../data/raw/sensor_readings.csv', parse_dates=['timestamp'])
df.head()
