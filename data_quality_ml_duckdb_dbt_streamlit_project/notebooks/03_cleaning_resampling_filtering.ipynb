# %% [markdown]
# # Cleaning, Resampling and Filtering
# Neste notebook aplicamos transformação de dados, resampling temporal e redução de ruído.

# %%
import pandas as pd
df = pd.read_csv('../data/raw/sensor_readings.csv', parse_dates=['timestamp'])
df.head()
