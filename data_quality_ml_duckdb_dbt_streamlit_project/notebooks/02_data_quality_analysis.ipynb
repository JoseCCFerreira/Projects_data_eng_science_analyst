# %% [markdown]
# # Data Quality Analysis
# Aqui avaliamos nulos, duplicados, outliers e atributos inconsistentes.

# %%
import pandas as pd
df = pd.read_csv('../data/raw/sensor_readings.csv', parse_dates=['timestamp'])
print(df.isna().sum())
