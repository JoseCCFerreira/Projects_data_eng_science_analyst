# %% [markdown]
# # Predictive Modeling
# Treino de modelos para prever o risco de falha e análise de métricas de performance.

# %%
import pandas as pd
df = pd.read_csv('../data/processed/clean_sensor_readings.csv', parse_dates=['timestamp'])
df.head()
